# %% [markdown]
# In Google Colab (or *Jupyter Notebooks*), commands are run:
# *   Starting with '!'\
# Shell command execution - It runs as a Linux shell (*terminal*) command instead of a Python code
# *   Begin without '!'\
# Python code execution - Colab treats it as a python code

# %% [markdown]
# ---

# %% [markdown]
# # Pre-requisites

# %% [markdown]
# Ensure to change runtime type and connect to a GPU (here, T4)

# %%
# !nvidia-smi
# Out:
# Fri Mar 14 05:23:24 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   60C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# *smi* in the above code stands for **S**ystem **M**anagement **I**nterface\
# It is a command line tool which provides information about the Nvidia GPU such as:
# *   GPU availability
# *   GPU model (Tesla T4, V100, A100)
# *   GPU memory usage
# *   Temperature and power usage
# *   Running processes using the GPU

# %% [markdown]
# ---
# \
# First, let's find the folder (directory) where the program is running on Colab and display its location.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ***import os***\
# It imports the *os* module, which provides functions for interacting with the operating system.\
# *os* can be thought of as a bridge in between Python and computer's file system.\
# The *os* module allows you to:\
# 1.Work with file paths and directories\
# 2.Perform system commands\
# 3.Handle environment variables\
# \
# ***HOME = os.getcwd( )***\
# *getcwd* stands for *get current working directory*.\
# It finds path of the directory where the script is currently running.\
# This path is stored in a variable HOME.\
# \
# ***print(HOME)***\
# It prints the path stored in variable HOME.

# %% [markdown]
# ---

# %% [markdown]
# # View workflow

# %% [markdown]
# Below program let's you run any of the 5 YOLOv8 models (v8n, v8s, v8m, v8l, v8x) on a .mp4 video file:
#
# Here's how the workflow looks like -
#
# 1.  Install necessary tools & libraries
# 2.  Download the .mp4 video file on which YOLOv8 is to be run
# 3.  Extract audio from the video
# 4.  Run YOLOv8 on the .mp4 video file
# 5.  Convert the .avi video file generated by YOLOv8 into .mp4
# 6.  Merge the extracted audio back with the video file
# 7.  Setup IPython to display video in Jupyter notebook i.e. in Colab itself

# %% [markdown]
# ---

# %% [markdown]
# # Step 1: Install necessary tools & libraries

# %%
# !pip install ultralytics==8.2.103 -q
# !pip install gdown
# !pip install ffmpeg
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.1/875.1 kB 27.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 86.6 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6082 sha256=e8c48250e164ab9d725a5f3ab69106200a8e3001990f91ac4a96b6e45ec6acd9
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4

# %% [markdown]
# ***pip***\
# It is a python package installer used to install libraries from the Python Package Index (*PyPI* ).\
# You can check for the downloaded files in the Folder on navigation bar on left.
#
# \
# ***ultralytics***\
# Package which contains YOLOv8, an object-detection and segmention model.\
# This package provides easy-to-use functions for training, fine-tuning and deploying YOLO models.\
# 8.2.103 specifies what version of that library is to be downloaded.\
# If version is not specified, i.e. (==8.2.103) is not used, pip installs the latest one.\
# A specific version might be needed to avoid compatibility issues.\
# *-* q stands for quiet mode, i.e. hides unnecessary installation messages (download progress bars, dependency checks).\
# Only important warnings or errors will be displayed.
#
# \
# ***gdown***\
# It is a python package used to download files from Google Drive using their URL IDs.\
# URL ID can be found enclosed within (..d/..) and (../view..) of an URL.\
# It only works if the file has been given public access drive, only then can it be downloaded using its URL.
#
# \
# ***ffmpeg***\
# It is an open-source tool for video editing, compression, streaming, and recording.\
# we have used it to extract & merge audio, stream video in this Jupyter notebook.

# %% [markdown]
# ---

# %% [markdown]
# # Step 2: Download the .mp4 video file

# %%
# !gdown --id 16oA7gk2KcF4yLGlPoCnnE4cqZWFYQ3H4 -O MasterChef_vid.mp4
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=16oA7gk2KcF4yLGlPoCnnE4cqZWFYQ3H4
# To: /content/MasterChef_vid.mp4
# 100% 79.6M/79.6M [00:02<00:00, 36.9MB/s]

# %% [markdown]
# URL ID has to be placed after '- - id'.\
# URL ID can be found enclosed within (..d/..) and (../view..) of an URL.\
# We can save the video file on Colab using a file name of our choice.\
# This file name has to be specified after '-0' along with the '.mp4' extension.\
# Here, we have saved the video with the name 'MasterChef_vid.mp4'

# %% [markdown]
# ---

# %% [markdown]
# # Step 3: Extract audio from the .mp4 video file

# %%
# !ffmpeg -i MasterChef_vid.mp4 -q:a 0 -map a audio.mp3
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'MasterChef_vid.mp4':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2025-01-05T10:05:33.000000Z
#     com.android.version: 14
#     com.android.manufacturer: motorola
#     com.android.model: moto g85 5G
#   Duration: 00:00:50.70, start: 0.000000, bitrate: 12565 kb/s
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 196 kb/s (default)
#     Metadata:
#       creation_time   : 2025-01-05T12:30:12.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt470bg/bt470bg/smpte170m), 1474x864, 12364 kb/s, 39.01 fps, 90k tbr, 90k tbn, 180k tbc (default)
#     Metadata:
#       creation_time   : 2025-01-05T12:30:12.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to 'audio.mp3':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.android.model: moto g85 5G
#     com.android.version: 14
#     com.android.manufacturer: motorola
#     TSSE            : Lavf58.76.100
#   Stream #0:0(eng): Audio: mp3, 44100 Hz, mono, fltp (default)
#     Metadata:
#       creation_time   : 2025-01-05T12:30:12.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# size=     787kB time=00:00:50.69 bitrate= 127.2kbits/s speed=99.2x
# video:0kB audio:787kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.054628%

# %% [markdown]
# Name of the video file from which audio is to be extracted has to be given after ' - i '.\
# The extracted audio file can be saved on Colab using a file name of our choice.\
# This file name has to be specified after ' - map a '.\
# Audio has been extracted from the video and saved as ' audio.mp3 ' and the ' MasterChef_vid.mp4 ' has become audioless.\
# Any file which has been generated by the program, can be seen in the Folder on left on the navigation bar.

# %% [markdown]
# ---

# %% [markdown]
# # Step 4: Run YOLOv8 on the audioless .mp4 video file

# %%
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8x.pt conf=0.7 source='/content/MasterChef_vid.mp4' save=True
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.7/112.6 GB disk)
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8x.pt to 'yolov8x.pt'...
# 100% 131M/131M [00:01<00:00, 85.4MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8x summary (fused): 268 layers, 68,200,608 parameters, 0 gradients, 257.8 GFLOPs
#
# video 1/1 (frame 1/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 62.3ms
# video 1/1 (frame 2/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 51.8ms
# video 1/1 (frame 3/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 51.9ms
# video 1/1 (frame 4/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 2 cups, 51.9ms
# video 1/1 (frame 5/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 2 cups, 31.6ms
# video 1/1 (frame 6/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 31.6ms
# video 1/1 (frame 7/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 31.5ms
# video 1/1 (frame 8/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 31.6ms
# video 1/1 (frame 9/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 31.5ms
# video 1/1 (frame 10/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 30.9ms
# video 1/1 (frame 11/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 30.1ms
# video 1/1 (frame 12/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 1 cup, 1 cake, 30.8ms
# video 1/1 (frame 13/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 2 cups, 1 cake, 31.5ms
# video 1/1 (frame 14/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 bottle, 2 cups, 1 cake, 30.2ms
# video 1/1 (frame 15/1978) /content/MasterChef_vid.mp4: 384x640 3 persons, 31.7ms
# video 1/1 (frame 16/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 31.4ms
# video 1/1 (frame 17/1978) /content/MasterChef_vid.mp4: 384x640 3 persons, 30.6ms
# video 1/1 (frame 18/1978) /content/MasterChef_vid.mp4: 384x640 3 persons, 30.5ms
# video 1/1 (frame 19/1978) /content/MasterChef_vid.mp4: 384x640 3 persons, 31.4ms
# video 1/1 (frame 20/1978) /content/MasterChef_vid.mp4: 384x640 3 persons, 31.6ms
# video 1/1 (frame 21/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 30.9ms
# video 1/1 (frame 22/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 30.1ms
# video 1/1 (frame 23/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 30.8ms
# video 1/1 (frame 24/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 31.0ms
# video 1/1 (frame 25/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 31.4ms
# video 1/1 (frame 26/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 31.5ms
# video 1/1 (frame 27/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 1 tie, 30.9ms
# video 1/1 (frame 28/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 30.7ms
# video 1/1 (frame 29/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 1 tie, 30.5ms
# video 1/1 (frame 30/1978) /content/MasterChef_vid.mp4: 384x640 4 persons, 30.9ms
# video 1/1 (frame
1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 carrot, 1 dining table, 37.2ms
# video 1/1 (frame 1977/1978) /content/MasterChef_vid.mp4: 384x640 1 person, 1 carrot, 1 dining table, 31.3ms
# video 1/1 (frame 1978/1978) /content/MasterChef_vid.mp4: 384x640 2 carrots, 1 dining table, 31.6ms
# Speed: 3.4ms preprocess, 32.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# 5 versions of YOLOv8 can be used -\
# **v8n** - *nano*, **v8s** - *small*, **v8m** - *medium*, **v8l** - *large*, **v8x** - *extra large*\
# Use the version of your choice in ' model=yolov8_.pt '\
# Accuracy and runtime of the models increases top-to-bottom.\
# \
# The parameter ***conf*** stands for confidence threshold.\
# It lies between 0 and 1.\
# Detections with confidence below 0.7 will be ignored.\
# Upon lowering its value (eg. conf=0.3), YOLO will detect more objects, but possibly with an increase in false detections.\
# Upon increasing it (eg. conf=0.9), detections will be more accurate but YOLO might miss some objects.\
# \
# Specify the path to .mp4 video file in source='__'\
# \
# The result is a .avi video file.\
# Its path can be found in the output as 'Results saved to **runs/detect/...**,

# %% [markdown]
# ---

# %% [markdown]
# # Step 5: Convert the .avi video file into .mp4

# %%
# !ffmpeg -i runs/detect/predict/MasterChef_vid.avi -c:v copy -c:a copy converted_vid.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from 'runs/detect/predict/MasterChef_vid.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:50.72, start: 0.000000, bitrate: 35242 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 1474x864, 35248 kb/s, 39 fps, 39 tbr, 39 tbn, 39 tbc
# Output #0, mp4, to 'converted_vid.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj420p(pc, bt470bg/unknown/unknown), 1474x864, q=2-31, 35248 kb/s, 39 fps, 39 tbr, 19968 tbn, 39 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Press [q] to stop, [?] for help
# frame= 1978 fps=0.0 q=-1.0 Lsize=  218131kB time=00:00:50.69 bitrate=35250.5kbits/s speed= 139x
# video:218121kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004773%

# %% [markdown]
# Ensure to replace runs/detect/predict with the path of the latest result which can be found in the previous output as -\
# 'Results saved to **runs/detect/predict**...'\
# eg. runs/detect/predict2 ,  runs/detect/predict3\
# \
# The .mp4 video generated can be saved with a file name of your choice, which has to specified after 'copy' alongwith the .mp4 file extension.

# %% [markdown]
# ---

# %% [markdown]
# # Step 6: Merge the extracted audio back with the video file

# %%
# !ffmpeg -i converted_vid.mp4 -i audio.mp3 -c:v copy -c:a aac -strict experimental almost_done.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'converted_vid.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:50.72, start: 0.000000, bitrate: 35232 kb/s
#   Stream #0:0(und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj420p(pc, bt470bg/unknown/unknown), 1474x864, 35231 kb/s, 39 fps, 39 tbr, 19968 tbn, 19968 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mp3, from 'audio.mp3':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     com.android.model: moto g85 5G
#     com.android.version: 14
#     com.android.manufacturer: motorola
#     encoder         : Lavf58.76.100
#   Duration: 00:00:50.73, start: 0.025057, bitrate: 127 kb/s
#   Stream #1:0: Audio: mp3, 44100 Hz, mono, fltp, 127 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #1:0 -> #0:1 (mp3 (mp3float) -> aac (native))
# Press [q] to stop, [?] for help
# Output #0, mp4, to 'almost_done.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj420p(pc, bt470bg/unknown/unknown), 1474x864, q=2-31, 35231 kb/s, 39 fps, 39 tbr, 19968 tbn, 19968 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
# frame= 1978 fps=0.0 q=-1.0 Lsize=  218588kB time=00:00:50.69 bitrate=35324.4kbits/s speed=59.8x
# video:218121kB audio:430kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.017335%
# [aac @ 0x5622e39c9b40] Qavg: 120.174

# %% [markdown]
# Now, the video file has audio.\
# It can be downloaded directly to your local device from the Folder on left.\
# The .mp4 video generated can be saved with a file name of your choice, which has to specified after 'experimental' alongwith the .mp4 file extension.

# %% [markdown]
# ---

# %% [markdown]
# # Step 7: Setup IPython to display video in Jupyter Notebook

# %%
from IPython import display
display.clear_output()
from IPython.display import display, Video

# %% [markdown]
# Videos can now be displayed in this Google Colab window

# %%
# !ffmpeg -i /content/almost_done.mp4 -c:v libx264 -c:a aac -strict experimental /content/required_vid.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/almost_done.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:50.72, start: 0.000000, bitrate: 35306 kb/s
#   Stream #0:0(und): Video: mjpeg (Baseline) (mp4v / 0x7634706D), yuvj420p(pc, bt470bg/unknown/unknown), 1474x864, 35231 kb/s, 39 fps, 39 tbr, 19968 tbn, 19968 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (aac (native) -> aac (native))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5bff07c8d4c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5bff07c8d4c0] profile High, level 3.2, 4:2:0, 8-bit
# [libx264 @ 0x5bff07c8d4c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/required_vid.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 1474x864, q=2-31, 39 fps, 19968 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 69 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 aac
# frame= 1978 fps= 14 q=-1.0 Lsize=   19639kB time=00:00:50.66 bitrate=3175.4kbits/s speed=0.355x
# video:19154kB audio:432kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.271663%
# [libx264 @ 0x5bff07c8d4c0] frame I:33    Avg QP:21.08  size: 74871
# [libx264 @ 0x5bff07c8d4c0] frame P:556   Avg QP:24.33  size: 20082
# [libx264 @ 0x5bff07c8d4c0] frame B:1389  Avg QP:26.63  size:  4303
# [libx264 @ 0x5bff07c8d4c0] consecutive B-frames:  3.6%  6.8%  4.2% 85.3%
# [libx264 @ 0x5bff07c8d4c0] mb I  I16..4: 15.4% 76.8%  7.8%
# [libx264 @ 0x5bff07c8d4c0] mb P  I16..4:  9.1% 24.4%  0.9%  P16..4: 27.8%  8.4%  3.9%  0.0%  0.0%    skip:25.6%
# [libx264 @ 0x5bff07c8d4c0] mb B  I16..4:  1.3%  2.8%  0.1%  B16..8: 26.6%  2.3%  0.3%  direct: 0.9%  skip:65.7%  L0:49.5% L1:47.4% BI: 3.1%
# [libx264 @ 0x5bff07c8d4c0] 8x8 transform intra:70.9% inter:85.5%
# [libx264 @ 0x5bff07c8d4c0] coded y,uvDC,uvAC intra: 42.6% 58.3% 8.8% inter: 6.1% 11.1% 1.8%
# [libx264 @ 0x5bff07c8d4c0] i16 v,h,dc,p: 35% 37%  8% 21%
# [libx264 @ 0x5bff07c8d4c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 29% 28%  3%  2%  3%  2%  2%  2%
# [libx264 @ 0x5bff07c8d4c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 37% 27% 11%  3%  5%  5%  4%  4%  3%
# [libx264 @ 0x5bff07c8d4c0] i8c dc,h,v,p: 40% 28% 28%  5%
# [libx264 @ 0x5bff07c8d4c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5bff07c8d4c0] ref P L0: 59.7% 13.5% 19.9%  6.8%
# [libx264 @ 0x5bff07c8d4c0] ref B L0: 85.6% 11.6%  2.7%
# [libx264 @ 0x5bff07c8d4c0] ref B L1: 95.3%  4.7%
# [libx264 @ 0x5bff07c8d4c0] kb/s:3093.61
# [aac @ 0x5bff07c73380] Qavg: 120.663

# %% [markdown]
# The video file also has to be converted in a format that can be displayed in Colab.\
# The end result will be the video with audio, YOLOv8 deployed on it, can be downloaded and run on any device.\
# You can change the name '**required_vid**' to any name of your choice.

# %%
display(Video("/content/required_vid.mp4", height=500, embed=True))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
